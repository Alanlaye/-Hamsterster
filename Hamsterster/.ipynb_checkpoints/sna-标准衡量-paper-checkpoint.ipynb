# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# 1. 加载边列表数据
edge_file = "out.petster-hamster-friend"
G = nx.read_edgelist(edge_file, nodetype=int, comments="%")

# %%
# 2. 绘制网络可视化图
plt.figure(figsize=(5, 4))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=False, node_size=10)
plt.title("Hamsterster Friends Network")
plt.savefig("network.png") # 保存图形为PNG文件
plt.show()

# %%
# 3.找出介数中心性最高的20个节点

# 计算所有节点的介数中心性
betweenness_centralities = nx.betweenness_centrality(G)

# 按照介数中心性对节点进行排序
sorted_nodes = sorted(betweenness_centralities.items(), key=lambda x: x[1], reverse=True)

# 选择介数中心性最高的20个节点
top_20_nodes = sorted_nodes[:20]

# 打印结果
for node, centrality in top_20_nodes:
    print(f"Node: {node}, Betweenness Centrality: {centrality}")
# Out:
# Node: 2539, Betweenness Centrality: 0.0795505758929833
# Node: 563, Betweenness Centrality: 0.059613573577993274
# Node: 646, Betweenness Centrality: 0.0533228509346257
# Node: 2579, Betweenness Centrality: 0.03863041164165817
# Node: 819, Betweenness Centrality: 0.035466794375009054
# Node: 2419, Betweenness Centrality: 0.03277672954551918
# Node: 1243, Betweenness Centrality: 0.02755783087230562
# Node: 65, Betweenness Centrality: 0.02684091295814566
# Node: 2176, Betweenness Centrality: 0.02657300119877968
# Node: 277, Betweenness Centrality: 0.02601471538748622
# Node: 30, Betweenness Centrality: 0.02225865535928285
# Node: 1016, Betweenness Centrality: 0.02206710560307024
# Node: 287, Betweenness Centrality: 0.021656833473438847
# Node: 1055, Betweenness Centrality: 0.01953149729569776
# Node: 2468, Betweenness Centrality: 0.018087198020861468
# Node: 2786, Betweenness Centrality: 0.018025397899915672
# Node: 280, Betweenness Centrality: 0.01800819372107515
# Node: 450, Betweenness Centrality: 0.017978632487067252
# Node: 2199, Betweenness Centrality: 0.0177147378576816
# Node: 1640, Betweenness Centrality: 0.0173703782171294

# %%
# 根据介数中心性的直方图分布大胆删去小于0.03的节点

import matplotlib.pyplot as plt

# 获取所有节点的介数中心性值
centrality_values = list(betweenness_centralities.values())

# 创建一个新的图形
plt.figure()

# 绘制直方图
plt.hist(centrality_values, bins=20)

# 设置标题和标签
plt.title('Betweenness Centrality Distribution')
plt.xlabel('Betweenness Centrality')
plt.ylabel('Number of Nodes')

# 显示图形
plt.show()

# %%
# 创建一个新的列表来存储介数中心性大于0.03的节点

filtered_nodes = [node for node, centrality in top_20_nodes if centrality >= 0.03]

# 打印结果
for node in filtered_nodes:
    print(f"Node: {node}, Betweenness Centrality: {betweenness_centralities[node]}")
# Out:
# Node: 2539, Betweenness Centrality: 0.0795505758929833
# Node: 563, Betweenness Centrality: 0.059613573577993274
# Node: 646, Betweenness Centrality: 0.0533228509346257
# Node: 2579, Betweenness Centrality: 0.03863041164165817
# Node: 819, Betweenness Centrality: 0.035466794375009054
# Node: 2419, Betweenness Centrality: 0.03277672954551918

# %%
# 4.网络约束系数

# 计算filtered_nodes中节点的网络约束系数
node_constraints = {node: nx.constraint(G, [node]) for node in filtered_nodes}

# 打印并筛选节点
for node, constraint in node_constraints.items():
    print(f"Node: {node}, Constraint: {constraint}")
# Out:
# Node: 2539, Constraint: {2539: 0.008421188386534616}
# Node: 563, Constraint: {563: 0.011527156777532724}
# Node: 646, Constraint: {646: 0.010331341492397941}
# Node: 2579, Constraint: {2579: 0.009662744286228344}
# Node: 819, Constraint: {819: 0.015935149962958365}
# Node: 2419, Constraint: {2419: 0.010072827130814921}

# %%
#  6.计算PageRank值
pageranks = nx.pagerank(G)

# 打印并筛选节点
for node in filtered_nodes:
    pagerank = pageranks[node]
    print(f"Node: {node}, PageRank: {pagerank}")
# Out:
# Node: 2539, PageRank: 0.008589396194066406
# Node: 563, PageRank: 0.004894631729785736
# Node: 646, PageRank: 0.005840573934959895
# Node: 2579, PageRank: 0.006642559402831097
# Node: 819, PageRank: 0.003506621810491485
# Node: 2419, PageRank: 0.005374728806705937

# %%
# 计算所有节点的PageRank值
pageranks = nx.pagerank(G)

# 按照PageRank值对节点进行排序
sorted_nodes = sorted(pageranks.items(), key=lambda x: x[1], reverse=True)

# 选择PageRank值最高的20个节点
top_20_nodes = sorted_nodes[:20]

# 打印结果
for node, pagerank in top_20_nodes:
    print(f"Node: {node}, PageRank: {pagerank}")
# Out:
# Node: 2539, PageRank: 0.008589396194066406
# Node: 2579, PageRank: 0.006642559402831097
# Node: 646, PageRank: 0.005840573934959895
# Node: 2419, PageRank: 0.005374728806705937
# Node: 563, PageRank: 0.004894631729785736
# Node: 65, PageRank: 0.004542027360277951
# Node: 2524, PageRank: 0.004434942787693681
# Node: 2610, PageRank: 0.0039868784472852905
# Node: 277, PageRank: 0.0039814797801454565
# Node: 1016, PageRank: 0.0038788257533177444
# Node: 2199, PageRank: 0.0038459643485952645
# Node: 2208, PageRank: 0.0037576759787791383
# Node: 2611, PageRank: 0.003552690833824365
# Node: 2187, PageRank: 0.0035402760925311466
# Node: 819, PageRank: 0.003506621810491485
# Node: 2176, PageRank: 0.003438105862603015
# Node: 280, PageRank: 0.003403881660799452
# Node: 2476, PageRank: 0.003393957833302244
# Node: 2786, PageRank: 0.0033415521173764235
# Node: 2219, PageRank: 0.003226135666694363

# %%
# 7. 计算局部聚类系数

# 计算filtered_nodes中节点的局部聚类系数
local_clustering_coefficients = nx.clustering(G, nodes=filtered_nodes)

# 打印结果
for node, coeff in local_clustering_coefficients.items():
    print(f"Node: {node}, Local Clustering Coefficient: {coeff}")
# Out:
# Node: 2539, Local Clustering Coefficient: 0.05727696982852182
# Node: 563, Local Clustering Coefficient: 0.06600478029049457
# Node: 646, Local Clustering Coefficient: 0.024787997390737115
# Node: 2579, Local Clustering Coefficient: 0.06628347804818394
# Node: 819, Local Clustering Coefficient: 0.04143277198609997
# Node: 2419, Local Clustering Coefficient: 0.045787545787545784

# %%
# 8.计算桥接中心度 

import community as community_louvain  # 导入Louvain社区检测库
partition = community_louvain.best_partition(G) # 使用Louvain算法检测社区

community_nodes = {}  # 创建一个字典来存储每个社区的节点
for node, community in partition.items():
    if community not in community_nodes:
        community_nodes[community] = []
    community_nodes[community].append(node)

bridge_nodes = []  # 存储桥接节点
for node in G.nodes():
    communities = set()  # 存储节点连接的社区
    for neighbor in G.neighbors(node):
        communities.add(partition[neighbor])
    if len(communities) > 1:  # 如果节点连接了多个社区，那么它就是一个桥接节点
        bridge_nodes.append(node)

# %%
bridge_degree = {}  # 存储每个节点的桥接度
for node in bridge_nodes:
    communities = set()  # 存储节点连接的社区
    for neighbor in G.neighbors(node):
        communities.add(partition[neighbor])
    bridge_degree[node] = len(communities)  # 桥接度等于节点连接的社区数量

print("Bridge Degree:")
for node, degree in bridge_degree.items():
    print(f"Node {node}: Bridge Degree = {degree}")
# Out:
# Bridge Degree:
# Node 7: Bridge Degree = 6
# Node 13: Bridge Degree = 4
# Node 15: Bridge Degree = 4
# Node 11: Bridge Degree = 4
# Node 21: Bridge Degree = 9
# Node 12: Bridge Degree = 4
# Node 23: Bridge Degree = 5
# Node 44: Bridge Degree = 3
# Node 52: Bridge Degree = 5
# Node 22: Bridge Degree = 7
# Node 53: Bridge Degree = 5
# Node 54: Bridge Degree = 5
# Node 55: Bridge Degree = 5
# Node 41: Bridge Degree = 2
# Node 57: Bridge Degree = 5
# Node 65: Bridge Degree = 7
# Node 30: Bridge Degree = 7
# Node 33: Bridge Degree = 2
# Node 66: Bridge Degree = 6
# Node 34: Bridge Degree = 2
# Node 35: Bridge Degree = 2
# Node 68: Bridge Degree = 2
# Node 69: Bridge Degree = 3
# Node 79: Bridge Degree = 3
# Node 84: Bridge Degree = 2
# Node 90: Bridge Degree = 2
# Node 91: Bridge Degree = 5
# Node 85: Bridge Degree = 4
# Node 92: Bridge Degree = 6
# Node 94: Bridge Degree = 7
# Node 67: Bridge Degree = 2
# Node 75: Bridge Degree = 2
# Node 95: Bridge Degree = 4
# Node 96: Bridge Degree = 5
# Node 97: Bridge Degree = 2
# Node 98: Bridge Degree = 3
# Node 99: Bridge Degree = 5
# Node 109: Bridge Degree = 4
# Node 103: Bridge Degree = 2
# Node 116: Bridge Degree = 9
# Node 113: Bridge Degree = 4
# Node 118: Bridge Degree = 3
# Node 121: Bridge Degree = 4
# Node 123: Bridge Degree = 7
# Node 125: Bridge Degree = 2
# Node 126: Bridge Degree = 2
# Node 128: Bridge Degree = 3
# Node 16: Bridge Degree = 2
# Node 131: Bridge Degree = 6
# Node 119: Bridge Degree = 4
# Node 133: Bridge Degree = 7
# Node 120: Bridge Degree = 4
# Node 135: Bridge Degree = 4
# Node 136: Bridge Degree = 7
# Node 144: Bridge Degree = 7
# Node 145: Bridge Degree = 6
# Node 132: Bridge Degree = 3
# Node 146: Bridge Degree = 9
# Node 127: Bridge Degree = 2
# Node 129: Bridge Degree = 2
# Node 130: Bridge Degree = 5
# Node 134: Bridge Degree = 5
# Node 147: Bridge Degree = 6
# Node 149: Bridge Degree = 4
# Node 152: Bridge Degree = 4
# Node 158: Bridge Degree = 2
# Node 159: Bridge Degree = 2
# Node 160: Bridge Degree = 2
# Node 161: Bridge Degree = 3
# Node 162: Bridge Degree = 2
# Node 163: Bridge Degree = 2
# Node 164: Bridge Degree = 5
# Node 165: Bridge Degree = 6
# Node 167: Bridge Degree = 3
# Node 172: Bridge Degree = 3
# Node 173: Bridge Degree = 3
# Node 174: Bridge Degree = 4
# Node 176: Bridge Degree = 4
# Node 179: Bridge Degree = 2
# Node 180: Bridge Degree = 4
# Node 100: Bridge Degree = 4
# Node 190: Bridge Degree = 8
# Node 188: Bridge Degree = 2
# Node 189: Bridge Degree = 2
# Node 192: Bridge Degree = 3
# Node 193: Bridge Degree = 3
# Node 198: Bridge Degree = 2
# Node 197: Bridge Degree = 2
# Node 203: Bridge Degree = 3
# Node 204: Bridge Degree = 3
# Node 206: Bridge Degree = 3
# Node 207: Bridge Degree = 5
# Node 214: Bridge Degree = 2
# Node 220: Bridge Degree = 4
# Node 151: Bridge Degree = 3
# Node 222: Bridge Degree = 4
# Node 224: Bridge Degree = 7
# Node 229: Bridge Degree = 2
# Node 230: Bridge Degree = 7
# Node 39: Bridge Degree = 2
# Node 231: Bridge Degree = 3
# Node 232: Bridge Degree = 2
# Node 237: Bridge Degree = 5
# Node 238: Bridge Degree = 5
# Node 239: Bridge Degree = 5
# Node 243: Bridge Degree = 5
# Node 244: Bridge Degree = 6
# Node 245: Bridge Degree = 5
# Node 246: Bridge Degree = 6
# Node 247: Bridge Degree = 6
# Node 248: Bridge Degree = 8
# Node 225: Bridge Degree = 2
# Node 227: Bridge Degree = 2
# Node 249: Bridge Degree = 6
# Node 226: Bridge Degree = 2
# Node 250: Bridge Degree = 4
# Node 252: Bridge Degree = 4
# Node 253: Bridge Degree = 3
# Node 255: Bridge Degree = 3
# Node 256: Bridge Degree = 4
# Node 257: Bridge Degree = 5
# Node 258: Bridge Degree = 2
# Node 259: Bridge Degree = 4
# Node 271: Bridge Degree = 2
# Node 274: Bridge Degree = 2
# Node 277: Bridge Degree = 8
# Node 186: Bridge Degree = 2
# Node 280: Bridge Degree = 8
# Node 286: Bridge Degree = 7
# Node 287: Bridge Degree = 7
# Node 289: Bridge Degree = 7
# Node 233: Bridge Degree = 3
# Node 300: Bridge Degree = 2
# Node 302: Bridge Degree = 2
# Node 303: Bridge Degree = 2
# Node 305: Bridge Degree = 2
# Node 307: Bridge Degree = 3
# Node 309: Bridge Degree = 3
# Node 285: Bridge Degree = 3
# Node 311: Bridge Degree = 2
# Node 315: Bridge Degree = 3
# Node 316: Bridge Degree = 6
# Node 320: Bridge Degree = 5
# Node 201: Bridge Degree = 5
# Node 202: Bridge Degree = 6
# Node 322: Bridge Degree = 5
# Node 323: Bridge Degree = 7
# Node 325: Bridge Degree = 5
# Node 329: Bridge Degree = 4
# Node 330: Bridge Degree = 3
# Node 340: Bridge Degree = 2
# Node 341: Bridge Degree = 2
# Node 342: Bridge Degree = 3
# Node 345: Bridge Degree = 6
# Node 348: Bridge Degree = 6
# Node 354: Bridge Degree = 2
# Node 363: Bridge Degree = 3
# Node 376: Bridge Degree = 7
# Node 377: Bridge Degree = 2
# Node 379: Bridge Degree = 3
# Node 386: Bridge Degree = 4
# Node 388: Bridge Degree = 2
# Node 390: Bridge Degree = 2
# Node 395: Bridge Degree = 5
# Node 394: Bridge Degree = 2
# Node 396: Bridge Degree = 5
# Node 397: Bridge Degree = 4
# Node 410: Bridge Degree = 5
# Node 411: Bridge Degree = 6
# Node 415: Bridge Degree = 5
# Node 417: Bridge Degree = 5
# Node 421: Bridge Degree = 5
# Node 422: Bridge Degree = 4
# Node 423: Bridge Degree = 4
# Node 426: Bridge Degree = 2
# Node 428: Bridge Degree = 2
# Node 429: Bridge Degree = 2
# Node 430: Bridge Degree = 2
# Node 431: Bridge Degree = 2
# Node 433: Bridge Degree = 2
# Node 447: Bridge Degree = 5
# Node 449: Bridge Degree = 2
# Node 450: Bridge Degree = 8
# Node 412: Bridge Degree = 2
# Node 451: Bridge Degree = 2
# Node 452: Bridge Degree = 2
# Node 453: Bridge Degree = 3
# Node 458: Bridge Degree = 3
# Node 459: Bridge Degree = 2
# Node 460: Bridge Degree = 4
# Node 462: Bridge Degree = 2
# Node 468: Bridge Degree = 5
# Node 469: Bridge Degree = 7
# Node 470: Bridge Degree = 7
# Node 471: Bridge Degree = 2
# Node 476: Bridge Degree = 3
# Node 481: Bridge Degree = 5
# Node 482: Bridge Degree = 3
# Node 484: Bridge Degree = 5
# Node 483: Bridge Degree = 4
# Node 485: Bridge Degree = 4
# Node 486: Bridge Degree = 6
# Node 385: Bridge Degree = 3
# Node 487: Bridge Degree = 4
# Node 488: Bridge Degree = 3
# Node 492: Bridge Degree = 4
# Node 494: Bridge Degree = 3
# Node 498: Bridge Degree = 5
# Node 501: Bridge Degree = 5
# Node 505: Bridge Degree = 3
# Node 461: Bridge Degree = 2
# Node 511: Bridge Degree = 2
# Node 512: Bridge Degree = 4
# Node 515: Bridge Degree = 2
# Node 517: Bridge Degree = 3
# Node 518: Bridge Degree = 3
# Node 521: Bridge Degree = 3
# Node 523: Bridge Degree = 5
# Node 525: Bridge Degree = 2
# Node 528: Bridge Degree = 2
# Node 529: Bridge Degree = 2
# Node 530: Bridge Degree = 3
# Node 522: Bridge Degree = 2
# Node 531: Bridge Degree = 6
# Node 533: Bridge Degree = 2
# Node 538: Bridge Degree = 3
# Node 539: Bridge Degree = 4
# Node 540: Bridge Degree = 2
# Node 543: Bridge Degree = 4
# Node 547: Bridge Degree = 2
# Node 551: Bridge Degree = 7
# Node 563: Bridge Degree = 9
# Node 564: Bridge Degree = 2
# Node 565: Bridge Degree = 2
# Node 566: Bridge Degree = 2
# Node 567: Bridge Degree = 2
# Node 568: Bridge Degree = 2
# Node 569: Bridge Degree = 5
# Node 570: Bridge Degree = 5
# Node 571: Bridge Degree = 6
# Node 573: Bridge Degree = 6
# Node 575: Bridge Degree = 2
# Node 577: Bridge Degree = 4
# Node 580: Bridge Degree = 5
# Node 585: Bridge Degree = 2
# Node 586: Bridge Degree = 2
# Node 587: Bridge Degree = 2
# Node 588: Bridge Degree = 4
# Node 589: Bridge Degree = 2
# Node 593: Bridge Degree = 2
# Node 594: Bridge Degree = 5
# Node 595: Bridge Degree = 2
# Node 599: Bridge Degree = 2
# Node 600: Bridge Degree = 2
# Node 601: Bridge Degree = 3
# Node 603: Bridge Degree = 2
# Node 604: Bridge Degree = 2
# Node 605: Bridge Degree = 4
# Node 607: Bridge Degree = 2
# Node 609: Bridge Degree = 2
# Node 616: Bridge Degree = 4
# Node 617: Bridge Degree = 4
# Node 381: Bridge Degree = 2
# Node 622: Bridge Degree = 2
# Node 624: Bridge Degree = 3
# Node 627: Bridge Degree = 6
# Node 628: Bridge Degree = 6
# Node 629: Bridge Degree = 8
# Node 630: Bridge Degree = 6
# Node 631: Bridge Degree = 6
# Node 632: Bridge Degree = 6
# Node 633: Bridge Degree = 7
# Node 212: Bridge Degree = 4
# Node 635: Bridge Degree = 7
# Node 636: Bridge Degree = 8
# Node 637: Bridge Degree = 4
# Node 638: Bridge Degree = 3
# Node 640: Bridge Degree = 4
# Node 641: Bridge Degree = 2
# Node 642: Bridge Degree = 3
# Node 643: Bridge Degree = 3
# Node 644: Bridge Degree = 3
# Node 645: Bridge Degree = 2
# Node 646: Bridge Degree = 8
# Node 378: Bridge Degree = 3
# Node 649: Bridge Degree = 6
# Node 652: Bridge Degree = 6
# Node 654: Bridge Degree = 4
# Node 655: Bridge Degree = 5
# Node 657: Bridge Degree = 2
# Node 660: Bridge Degree = 6
# Node 661: Bridge Degree = 4
# Node 662: Bridge Degree = 2
# Node 665: Bridge Degree = 3
# Node 668: Bridge Degree = 3
# Node 669: Bridge Degree = 2
# Node 674: Bridge Degree = 7
# Node 675: Bridge Degree = 3
# Node 678: Bridge Degree = 3
# Node 679: Bridge Degree = 2
# Node 680: Bridge Degree = 2
# Node 681: Bridge Degree = 2
# Node 687: Bridge Degree = 4
# Node 693: Bridge Degree = 3
# Node 703: Bridge Degree = 2
# Node 706: Bridge Degree = 3
# Node 711: Bridge Degree = 2
# Node 712: Bridge Degree = 3
# Node 713: Bridge Degree = 3
# Node 716: Bridge Degree = 3
# Node 717: Bridge Degree = 3
# Node 718: Bridge Degree = 2
# Node 719: Bridge Degree = 2
# Node 725: Bridge Degree = 5
# Node 726: Bridge Degree = 3
# Node 727: Bridge Degree = 7
# Node 729: Bridge Degree = 2
# Node 732: Bridge Degree = 2
# Node 741: Bridge Degree = 3
# Node 742: Bridge Degree = 3
# Node 743: Bridge Degree = 7
# Node 746: Bridge Degree = 6
# Node 748: Bridge Degree = 8
# Node 749: Bridge Degree = 3
# Node 750: Bridge Degree = 4
# Node 751: Bridge Degree = 2
# Node 753: Bridge Degree = 2
# Node 757: Bridge Degree = 3
# Node 761: Bridge Degree = 6
# Node 763: Bridge Degree = 2
# Node 764: Bridge Degree = 3
# Node 768: Bridge Degree = 6
# Node 769: Bridge Degree = 5
# Node 770: Bridge Degree = 6
# Node 771: Bridge Degree = 5
# Node 772: Bridge Degree = 5
# Node 774: Bridge Degree = 4
# Node 775: Bridge Degree = 3
# Node 777: Bridge Degree = 2
# Node 779: Bridge Degree = 5
# Node 780: Bridge Degree = 3
# Node 781: Bridge Degree = 4
# Node 785: Bridge Degree = 4
# Node 791: Bridge Degree = 2
# Node 792: Bridge Degree = 3
# Node 793: Bridge Degree = 6
# Node 796: Bridge Degree = 4
# Node 797: Bridge Degree = 3
# Node 659: Bridge Degree = 3
# Node 803: Bridge Degree = 2
# Node 572: Bridge Degree = 2
# Node 808: Bridge Degree = 4
# Node 815: Bridge Degree = 4
# Node 477: Bridge Degree = 2
# Node 817: Bridge Degree = 2
# Node 818: Bridge Degree = 2
# Node 819: Bridge Degree = 10
# Node 821: Bridge Degree = 2
# Node 822: Bridge Degree = 4
# Node 824: Bridge Degree = 3
# Node 827: Bridge Degree = 2
# Node 830: Bridge Degree = 2
# Node 832: Bridge Degree = 2
# Node 833: Bridge Degree = 2
# Node 834: Bridge Degree = 2
# Node 835: Bridge Degree = 2
# Node 836: Bridge Degree = 2
# Node 837: Bridge Degree = 2
# Node 838: Bridge Degree = 2
# Node 839: Bridge Degree = 2
# Node 840: Bridge Degree = 2
# Node 841: Bridge Degree = 7
# Node 846: Bridge Degree = 5
# Node 849: Bridge Degree = 3
# Node 853: Bridge Degree = 7
# Node 862: Bridge Degree = 5
# Node 863: Bridge Degree = 4
# Node 864: Bridge Degree = 5
# Node 865: Bridge Degree = 3
# Node 868: Bridge Degree = 2
# Node 871: Bridge Degree = 3
# Node 872: Bridge Degree = 7
# Node 873: Bridge Degree = 7
# Node 878: Bridge Degree = 2
# Node 880: Bridge Degree = 4
# Node 881: Bridge Degree = 2
# Node 882: Bridge Degree = 2
# Node 884: Bridge Degree = 6
# Node 885: Bridge Degree = 6
# Node 886: Bridge Degree = 5
# Node 888: Bridge Degree = 2
# Node 891: Bridge Degree = 2
# Node 892: Bridge Degree = 2
# Node 893: Bridge Degree = 2
# Node 894: Bridge Degree = 2
# Node 896: Bridge Degree = 3
# Node 897: Bridge Degree = 2
# Node 898: Bridge Degree = 2
# Node 899: Bridge Degree = 2
# Node 900: Bridge Degree = 2
# Node 904: Bridge Degree = 4
# Node 905: Bridge Degree = 4
# Node 908: Bridge Degree = 3
# Node 909: Bridge Degree = 2
# Node 910: Bridge Degree = 3
# Node 916: Bridge Degree = 2
# Node 918: Bridge Degree = 3
# Node 919: Bridge Degree = 2
# Node 922: Bridge Degree = 2
# Node 923: Bridge Degree = 2
# Node 926: Bridge Degree = 4
# Node 928: Bridge Degree = 4
# Node 932: Bridge Degree = 4
# Node 934: Bridge Degree = 3
# Node 935: Bridge Degree = 3
# Node 936: Bridge Degree = 4
# Node 939: Bridge Degree = 2
# Node 940: Bridge Degree = 4
# Node 944: Bridge Degree = 3
# Node 945: Bridge Degree = 6
# Node 948: Bridge Degree = 3
# Node 951: Bridge Degree = 4
# Node 953: Bridge Degree = 2
# Node 956: Bridge Degree = 3
# Node 957: Bridge Degree = 2
# Node 961: Bridge Degree = 3
# Node 962: Bridge Degree = 3
# Node 963: Bridge Degree = 3
# Node 964: Bridge Degree = 3
# Node 969: Bridge Degree = 3
# Node 977: Bridge Degree = 2
# Node 979: Bridge Degree = 2
# Node 982: Bridge Degree = 2
# Node 983: Bridge Degree = 2
# Node 984: Bridge Degree = 6
# Node 987: Bridge Degree = 2
# Node 988: Bridge Degree = 3
# Node 989: Bridge Degree = 4
# Node 990: Bridge Degree = 5
# Node 991: Bridge Degree = 5
# Node 997: Bridge Degree = 2
# Node 998: Bridge Degree = 2
# Node 1007: Bridge Degree = 2
# Node 1008: Bridge Degree = 2
# Node 1009: Bridge Degree = 5
# Node 1014: Bridge Degree = 7
# Node 1015: Bridge Degree = 3
# Node 1016: Bridge Degree = 5
# Node 1017: Bridge Degree = 3
# Node 1019: Bridge Degree = 2
# Node 1021: Bridge Degree = 2
# Node 1023: Bridge Degree = 2
# Node 1024: Bridge Degree = 2
# Node 1025: Bridge Degree = 2
# Node 1026: Bridge Degree = 4
# Node 1027: Bridge Degree = 4
# Node 1029: Bridge Degree = 2
# Node 1030: Bridge Degree = 2
# Node 1031: Bridge Degree = 2
# Node 1032: Bridge Degree = 2
# Node 1033: Bridge Degree = 7
# Node 74: Bridge Degree = 2
# Node 1034: Bridge Degree = 2
# Node 1042: Bridge Degree = 4
# Node 1043: Bridge Degree = 4
# Node 1047: Bridge Degree = 2
# Node 1051: Bridge Degree = 2
# Node 1052: Bridge Degree = 2
# Node 1053: Bridge Degree = 2
# Node 1054: Bridge Degree = 3
# Node 1055: Bridge Degree = 7
# Node 384: Bridge Degree = 3
# Node 1057: Bridge Degree = 2
# Node 1058: Bridge Degree = 2
# Node 1061: Bridge Degree = 2
# Node 1062: Bridge Degree = 2
# Node 1063: Bridge Degree = 2
# Node 1064: Bridge Degree = 2
# Node 1066: Bridge Degree = 6
# Node 1068: Bridge Degree = 4
# Node 1070: Bridge Degree = 5
# Node 1060: Bridge Degree = 3
# Node 1077: Bridge Degree = 2
# Node 1078: Bridge Degree = 2
# Node 1081: Bridge Degree = 3
# Node 1076: Bridge Degree = 2
# Node 1083: Bridge Degree = 3
# Node 1094: Bridge Degree = 6
# Node 1101: Bridge Degree = 3
# Node 1116: Bridge Degree = 2
# Node 1119: Bridge Degree = 6
# Node 1126: Bridge Degree = 2
# Node 1128: Bridge Degree = 3
# Node 1130: Bridge Degree = 2
# Node 1131: Bridge Degree = 2
# Node 1132: Bridge Degree = 2
# Node 1134: Bridge Degree = 2
# Node 1135: Bridge Degree = 2
# Node 1136: Bridge Degree = 4
# Node 1138: Bridge Degree = 4
# Node 1139: Bridge Degree = 2
# Node 1141: Bridge Degree = 2
# Node 1145: Bridge Degree = 3
# Node 1146: Bridge Degree = 3
# Node 1147: Bridge Degree = 2
# Node 1157: Bridge Degree = 2
# Node 1158: Bridge Degree = 5
# Node 1159: Bridge Degree = 2
# Node 1160: Bridge Degree = 2
# Node 1164: Bridge Degree = 3
# Node 1165: Bridge Degree = 2
# Node 1166: Bridge Degree = 2
# Node 1167: Bridge Degree = 2
# Node 1172: Bridge Degree = 2
# Node 1173: Bridge Degree = 3
# Node 1174: Bridge Degree = 5
# Node 1176: Bridge Degree = 2
# Node 1177: Bridge Degree = 3
# Node 1178: Bridge Degree = 3
# Node 1180: Bridge Degree = 3
# Node 1184: Bridge Degree = 3
# Node 1191: Bridge Degree = 2
# Node 1197: Bridge Degree = 3
# Node 1198: Bridge Degree = 6
# Node 1208: Bridge Degree = 5
# Node 1212: Bridge Degree = 2
# Node 1214: Bridge Degree = 3
# Node 1218: Bridge Degree = 5
# Node 1223: Bridge Degree = 4
# Node 1224: Bridge Degree = 4
# Node 1226: Bridge Degree = 2
# Node 1228: Bridge Degree = 2
# Node 1229: Bridge Degree = 2
# Node 1237: Bridge Degree = 4
# Node 1243: Bridge Degree = 7
# Node 1246: Bridge Degree = 5
# Node 1249: Bridge Degree = 4
# Node 1253: Bridge Degree = 2
# Node 1256: Bridge Degree = 2
# Node 1258: Bridge Degree = 2
# Node 1261: Bridge Degree = 3
# Node 1267: Bridge Degree = 2
# Node 1268: Bridge Degree = 6
# Node 1272: Bridge Degree = 3
# Node 1278: Bridge Degree = 3
# Node 1285: Bridge Degree = 6
# Node 1286: Bridge Degree = 5
# Node 1287: Bridge Degree = 5
# Node 1288: Bridge Degree = 6
# Node 1293: Bridge Degree = 2
# Node 1305: Bridge Degree = 2
# Node 1306: Bridge Degree = 2
# Node 1309: Bridge Degree = 2
# Node 1310: Bridge Degree = 2
# Node 1311: Bridge Degree = 2
# Node 1312: Bridge Degree = 2
# Node 1319: Bridge Degree = 2
# Node 1321: Bridge Degree = 3
# Node 1322: Bridge Degree = 7
# Node 1323: Bridge Degree = 7
# Node 1324: Bridge Degree = 7
# Node 1325: Bridge Degree = 7
# Node 1327: Bridge Degree = 4
# Node 1328: Bridge Degree = 3
# Node 1329: Bridge Degree = 3
# Node 1220: Bridge Degree = 3
# Node 1330: Bridge Degree = 2
# Node 1316: Bridge Degree = 2
# Node 1333: Bridge Degree = 2
# Node 1334: Bridge Degree = 2
# Node 1335: Bridge Degree = 2
# Node 1336: Bridge Degree = 2
# Node 1337: Bridge Degree = 2
# Node 1338: Bridge Degree = 6
# Node 1339: Bridge Degree = 2
# Node 1340: Bridge Degree = 2
# Node 1342: Bridge Degree = 2
# Node 1346: Bridge Degree = 2
# Node 1350: Bridge Degree = 3
# Node 1351: Bridge Degree = 2
# Node 1352: Bridge Degree = 2
# Node 1358: Bridge Degree = 2
# Node 1363: Bridge Degree = 2
# Node 1369: Bridge Degree = 2
# Node 1374: Bridge Degree = 2
# Node 1375: Bridge Degree = 2
# Node 28: Bridge Degree = 2
# Node 1384: Bridge Degree = 2
# Node 1387: Bridge Degree = 3
# Node 1389: Bridge Degree = 4
# Node 1392: Bridge Degree = 3
# Node 1394: Bridge Degree = 2
# Node 1395: Bridge Degree = 2
# Node 1398: Bridge Degree = 3
# Node 1400: Bridge Degree = 2
# Node 1401: Bridge Degree = 2
# Node 1403: Bridge Degree = 2
# Node 1404: Bridge Degree = 2
# Node 1405: Bridge Degree = 2
# Node 1406: Bridge Degree = 2
# Node 1409: Bridge Degree = 3
# Node 1410: Bridge Degree = 4
# Node 1413: Bridge Degree = 2
# Node 1419: Bridge Degree = 2
# Node 1420: Bridge Degree = 2
# Node 1422: Bridge Degree = 7
# Node 1426: Bridge Degree = 3
# Node 1427: Bridge Degree = 3
# Node 1428: Bridge Degree = 2
# Node 1429: Bridge Degree = 2
# Node 1430: Bridge Degree = 2
# Node 1431: Bridge Degree = 4
# Node 1440: Bridge Degree = 2
# Node 1442: Bridge Degree = 5
# Node 1443: Bridge Degree = 2
# Node 1124: Bridge Degree = 2
# Node 1444: Bridge Degree = 3
# Node 1445: Bridge Degree = 3
# Node 1448: Bridge Degree = 4
# Node 1449: Bridge Degree = 4
# Node 1450: Bridge Degree = 4
# Node 1452: Bridge Degree = 4
# Node 1454: Bridge Degree = 2
# Node 1455: Bridge Degree = 2
# Node 1487: Bridge Degree = 5
# Node 235: Bridge Degree = 2
# Node 1488: Bridge Degree = 3
# Node 1489: Bridge Degree = 3
# Node 1490: Bridge Degree = 4
# Node 1491: Bridge Degree = 4
# Node 1493: Bridge Degree = 4
# Node 1499: Bridge Degree = 3
# Node 1504: Bridge Degree = 4
# Node 1507: Bridge Degree = 2
# Node 1515: Bridge Degree = 3
# Node 1535: Bridge Degree = 2
# Node 1536: Bridge Degree = 2
# Node 1538: Bridge Degree = 2
# Node 1546: Bridge Degree = 2
# Node 1547: Bridge Degree = 2
# Node 1548: Bridge Degree = 2
# Node 1556: Bridge Degree = 2
# Node 1567: Bridge Degree = 2
# Node 1578: Bridge Degree = 5
# Node 1581: Bridge Degree = 2
# Node 1589: Bridge Degree = 2
# Node 1600: Bridge Degree = 7
# Node 1607: Bridge Degree = 3
# Node 1608: Bridge Degree = 2
# Node 1610: Bridge Degree = 5
# Node 1621: Bridge Degree = 4
# Node 1640: Bridge Degree = 7
# Node 1650: Bridge Degree = 3
# Node 1655: Bridge Degree = 3
# Node 1663: Bridge Degree = 3
# Node 1664: Bridge Degree = 3
# Node 1672: Bridge Degree = 2
# Node 1682: Bridge Degree = 3
# Node 1692: Bridge Degree = 2
# Node 1693: Bridge Degree = 4
# Node 1694: Bridge Degree = 7
# Node 1705: Bridge Degree = 5
# Node 1716: Bridge Degree = 3
# Node 1721: Bridge Degree = 3
# Node 1722: Bridge Degree = 3
# Node 1723: Bridge Degree = 3
# Node 1726: Bridge Degree = 2
# Node 1737: Bridge Degree = 2
# Node 1743: Bridge Degree = 3
# Node 1745: Bridge Degree = 3
# Node 1746: Bridge Degree = 6
# Node 1747: Bridge Degree = 6
# Node 1748: Bridge Degree = 4
# Node 1755: Bridge Degree = 4
# Node 1766: Bridge Degree = 3
# Node 1776: Bridge Degree = 5
# Node 1787: Bridge Degree = 6
# Node 1790: Bridge Degree = 4
# Node 1794: Bridge Degree = 3
# Node 1797: Bridge Degree = 2
# Node 1810: Bridge Degree = 2
# Node 1811: Bridge Degree = 2
# Node 1812: Bridge Degree = 2
# Node 1813: Bridge Degree = 2
# Node 1814: Bridge Degree = 2
# Node 1816: Bridge Degree = 2
# Node 1817: Bridge Degree = 2
# Node 1824: Bridge Degree = 2
# Node 1871: Bridge Degree = 3
# Node 1662: Bridge Degree = 2
# Node 1886: Bridge Degree = 2
# Node 1895: Bridge Degree = 2
# Node 1896: Bridge Degree = 2
# Node 1897: Bridge Degree = 5
# Node 1898: Bridge Degree = 3
# Node 1900: Bridge Degree = 3
# Node 1909: Bridge Degree = 3
# Node 1920: Bridge Degree = 3
# Node 1929: Bridge Degree = 3
# Node 1930: Bridge Degree = 3
# Node 1937: Bridge Degree = 4
# Node 1948: Bridge Degree = 4
# Node 1968: Bridge Degree = 2
# Node 1999: Bridge Degree = 2
# Node 2000: Bridge Degree = 2
# Node 2006: Bridge Degree = 3
# Node 2047: Bridge Degree = 4
# Node 2058: Bridge Degree = 4
# Node 2069: Bridge Degree = 4
# Node 2089: Bridge Degree = 2
# Node 2165: Bridge Degree = 4
# Node 2176: Bridge Degree = 9
# Node 2187: Bridge Degree = 7
# Node 2198: Bridge Degree = 5
# Node 2199: Bridge Degree = 8
# Node 2208: Bridge Degree = 8
# Node 2219: Bridge Degree = 8
# Node 2229: Bridge Degree = 6
# Node 2240: Bridge Degree = 7
# Node 2250: Bridge Degree = 3
# Node 2251: Bridge Degree = 5
# Node 2252: Bridge Degree = 3
# Node 2257: Bridge Degree = 2
# Node 2282: Bridge Degree = 4
# Node 2292: Bridge Degree = 3
# Node 2118: Bridge Degree = 3
# Node 2302: Bridge Degree = 5
# Node 2303: Bridge Degree = 3
# Node 2314: Bridge Degree = 5
# Node 2331: Bridge Degree = 2
# Node 2333: Bridge Degree = 2
# Node 2336: Bridge Degree = 2
# Node 2337: Bridge Degree = 3
# Node 2340: Bridge Degree = 2
# Node 2341: Bridge Degree = 2
# Node 2342: Bridge Degree = 2
# Node 2343: Bridge Degree = 3
# Node 2344: Bridge Degree = 3
# Node 2345: Bridge Degree = 4
# Node 2347: Bridge Degree = 2
# Node 2348: Bridge Degree = 2
# Node 2349: Bridge Degree = 3
# Node 2350: Bridge Degree = 2
# Node 2351: Bridge Degree = 4
# Node 2352: Bridge Degree = 4
# Node 2353: Bridge Degree = 2
# Node 2354: Bridge Degree = 2
# Node 2355: Bridge Degree = 2
# Node 2356: Bridge Degree = 3
# Node 2357: Bridge Degree = 2
# Node 83: Bridge Degree = 2
# Node 2364: Bridge Degree = 3
# Node 2365: Bridge Degree = 3
# Node 2366: Bridge Degree = 2
# Node 2367: Bridge Degree = 5
# Node 2368: Bridge Degree = 5
# Node 2370: Bridge Degree = 3
# Node 2372: Bridge Degree = 3
# Node 2373: Bridge Degree = 3
# Node 2374: Bridge Degree = 3
# Node 2378: Bridge Degree = 3
# Node 2379: Bridge Degree = 5
# Node 2380: Bridge Degree = 5
# Node 2381: Bridge Degree = 5
# Node 2385: Bridge Degree = 2
# Node 2386: Bridge Degree = 4
# Node 2389: Bridge Degree = 3
# Node 2390: Bridge Degree = 2
# Node 2391: Bridge Degree = 4
# Node 2392: Bridge Degree = 3
# Node 2393: Bridge Degree = 5
# Node 2394: Bridge Degree = 3
# Node 2395: Bridge Degree = 3
# Node 2396: Bridge Degree = 5
# Node 2397: Bridge Degree = 3
# Node 2398: Bridge Degree = 7
# Node 2399: Bridge Degree = 2
# Node 2402: Bridge Degree = 6
# Node 2403: Bridge Degree = 2
# Node 2404: Bridge Degree = 2
# Node 2405: Bridge Degree = 3
# Node 2406: Bridge Degree = 2
# Node 2412: Bridge Degree = 2
# Node 2413: Bridge Degree = 2
# Node 2414: Bridge Degree = 6
# Node 2415: Bridge Degree = 3
# Node 2417: Bridge Degree = 6
# Node 2419: Bridge Degree = 8
# Node 2420: Bridge Degree = 2
# Node 2421: Bridge Degree = 7
# Node 2422: Bridge Degree = 3
# Node 2424: Bridge Degree = 2
# Node 2425: Bridge Degree = 2
# Node 2426: Bridge Degree = 2
# Node 2427: Bridge Degree = 3
# Node 2428: Bridge Degree = 3
# Node 2429: Bridge Degree = 6
# Node 2430: Bridge Degree = 5
# Node 2431: Bridge Degree = 5
# Node 2433: Bridge Degree = 4
# Node 2438: Bridge Degree = 2
# Node 2439: Bridge Degree = 7
# Node 219: Bridge Degree = 2
# Node 2441: Bridge Degree = 6
# Node 2448: Bridge Degree = 2
# Node 2451: Bridge Degree = 4
# Node 2453: Bridge Degree = 2
# Node 2454: Bridge Degree = 6
# Node 2456: Bridge Degree = 2
# Node 2457: Bridge Degree = 3
# Node 2458: Bridge Degree = 2
# Node 2459: Bridge Degree = 2
# Node 2460: Bridge Degree = 2
# Node 2461: Bridge Degree = 6
# Node 2462: Bridge Degree = 6
# Node 2463: Bridge Degree = 2
# Node 2465: Bridge Degree = 2
# Node 2466: Bridge Degree = 2
# Node 2468: Bridge Degree = 9
# Node 2470: Bridge Degree = 2
# Node 2471: Bridge Degree = 2
# Node 2472: Bridge Degree = 2
# Node 2474: Bridge Degree = 2
# Node 2475: Bridge Degree = 2
# Node 154: Bridge Degree = 2
# Node 2476: Bridge Degree = 5
# Node 2480: Bridge Degree = 2
# Node 2482: Bridge Degree = 3
# Node 2485: Bridge Degree = 3
# Node 2486: Bridge Degree = 2
# Node 2487: Bridge Degree = 4
# Node 2488: Bridge Degree = 4
# Node 2489: Bridge Degree = 3
# Node 2490: Bridge Degree = 4
# Node 2491: Bridge Degree = 5
# Node 2492: Bridge Degree = 3
# Node 2493: Bridge Degree = 2
# Node 2494: Bridge Degree = 2
# Node 2464: Bridge Degree = 2
# Node 2495: Bridge Degree = 2
# Node 2501: Bridge Degree = 4
# Node 2502: Bridge Degree = 2
# Node 2503: Bridge Degree = 2
# Node 2504: Bridge Degree = 2
# Node 2506: Bridge Degree = 2
# Node 2511: Bridge Degree = 6
# Node 2512: Bridge Degree = 4
# Node 2513: Bridge Degree = 2
# Node 2514: Bridge Degree = 3
# Node 2519: Bridge Degree = 4
# Node 2520: Bridge Degree = 2
# Node 2521: Bridge Degree = 3
# Node 2522: Bridge Degree = 6
# Node 2523: Bridge Degree = 7
# Node 2524: Bridge Degree = 8
# Node 2525: Bridge Degree = 2
# Node 2527: Bridge Degree = 5
# Node 2528: Bridge Degree = 3
# Node 2529: Bridge Degree = 2
# Node 2530: Bridge Degree = 2
# Node 2533: Bridge Degree = 2
# Node 2535: Bridge Degree = 4
# Node 2538: Bridge Degree = 2
# Node 2539: Bridge Degree = 10
# Node 2483: Bridge Degree = 2
# Node 2543: Bridge Degree = 5
# Node 2544: Bridge Degree = 2
# Node 2545: Bridge Degree = 6
# Node 2547: Bridge Degree = 3
# Node 2553: Bridge Degree = 2
# Node 2554: Bridge Degree = 2
# Node 2556: Bridge Degree = 2
# Node 2560: Bridge Degree = 2
# Node 2562: Bridge Degree = 2
# Node 2565: Bridge Degree = 2
# Node 2569: Bridge Degree = 3
# Node 2570: Bridge Degree = 5
# Node 2571: Bridge Degree = 2
# Node 2572: Bridge Degree = 3
# Node 2575: Bridge Degree = 3
# Node 2576: Bridge Degree = 4
# Node 2577: Bridge Degree = 4
# Node 2579: Bridge Degree = 9
# Node 2580: Bridge Degree = 2
# Node 2581: Bridge Degree = 2
# Node 2582: Bridge Degree = 2
# Node 2586: Bridge Degree = 2
# Node 2588: Bridge Degree = 3
# Node 2589: Bridge Degree = 3
# Node 2590: Bridge Degree = 3
# Node 2592: Bridge Degree = 3
# Node 2593: Bridge Degree = 3
# Node 2595: Bridge Degree = 2
# Node 2596: Bridge Degree = 3
# Node 2597: Bridge Degree = 2
# Node 2598: Bridge Degree = 2
# Node 2600: Bridge Degree = 2
# Node 2601: Bridge Degree = 3
# Node 2602: Bridge Degree = 2
# Node 2603: Bridge Degree = 2
# Node 2604: Bridge Degree = 2
# Node 2607: Bridge Degree = 4
# Node 2609: Bridge Degree = 2
# Node 2610: Bridge Degree = 7
# Node 2611: Bridge Degree = 6
# Node 2613: Bridge Degree = 3
# Node 2614: Bridge Degree = 2
# Node 2616: Bridge Degree = 2
# Node 2618: Bridge Degree = 2
# Node 2620: Bridge Degree = 3
# Node 2625: Bridge Degree = 5
# Node 2626: Bridge Degree = 3
# Node 2627: Bridge Degree = 6
# Node 2628: Bridge Degree = 5
# Node 2629: Bridge Degree = 3
# Node 2630: Bridge Degree = 4
# Node 2632: Bridge Degree = 3
# Node 2633: Bridge Degree = 3
# Node 855: Bridge Degree = 2
# Node 2635: Bridge Degree = 4
# Node 2640: Bridge Degree = 3
# Node 2641: Bridge Degree = 2
# Node 2646: Bridge Degree = 2
# Node 2648: Bridge Degree = 2
# Node 2650: Bridge Degree = 7
# Node 2651: Bridge Degree = 7
# Node 2655: Bridge Degree = 2
# Node 2657: Bridge Degree = 2
# Node 2658: Bridge Degree = 2
# Node 2661: Bridge Degree = 2
# Node 2662: Bridge Degree = 3
# Node 2663: Bridge Degree = 2
# Node 2664: Bridge Degree = 2
# Node 2665: Bridge Degree = 3
# Node 2671: Bridge Degree = 3
# Node 2672: Bridge Degree = 3
# Node 2673: Bridge Degree = 2
# Node 2674: Bridge Degree = 2
# Node 2680: Bridge Degree = 4
# Node 2684: Bridge Degree = 2
# Node 2685: Bridge Degree = 2
# Node 2689: Bridge Degree = 2
# Node 2693: Bridge Degree = 4
# Node 2695: Bridge Degree = 4
# Node 2698: Bridge Degree = 7
# Node 2702: Bridge Degree = 4
# Node 2703: Bridge Degree = 2
# Node 2704: Bridge Degree = 2
# Node 2706: Bridge Degree = 2
# Node 2707: Bridge Degree = 2
# Node 2708: Bridge Degree = 2
# Node 2709: Bridge Degree = 4
# Node 2710: Bridge Degree = 4
# Node 2712: Bridge Degree = 2
# Node 2713: Bridge Degree = 3
# Node 2714: Bridge Degree = 3
# Node 2715: Bridge Degree = 3
# Node 2716: Bridge Degree = 3
# Node 2724: Bridge Degree = 2
# Node 2730: Bridge Degree = 8
# Node 2731: Bridge Degree = 3
# Node 2732: Bridge Degree = 3
# Node 2736: Bridge Degree = 4
# Node 2737: Bridge Degree = 4
# Node 2738: Bridge Degree = 4
# Node 2740: Bridge Degree = 2
# Node 2741: Bridge Degree = 4
# Node 2742: Bridge Degree = 4
# Node 2743: Bridge Degree = 4
# Node 2744: Bridge Degree = 4
# Node 2746: Bridge Degree = 4
# Node 2747: Bridge Degree = 4
# Node 2748: Bridge Degree = 4
# Node 2749: Bridge Degree = 6
# Node 2750: Bridge Degree = 6
# Node 2751: Bridge Degree = 2
# Node 2755: Bridge Degree = 5
# Node 2756: Bridge Degree = 4
# Node 2757: Bridge Degree = 6
# Node 2758: Bridge Degree = 5
# Node 2759: Bridge Degree = 2
# Node 2760: Bridge Degree = 2
# Node 2761: Bridge Degree = 2
# Node 2762: Bridge Degree = 2
# Node 2767: Bridge Degree = 4
# Node 2768: Bridge Degree = 4
# Node 2769: Bridge Degree = 3
# Node 2772: Bridge Degree = 2
# Node 2773: Bridge Degree = 2
# Node 2774: Bridge Degree = 4
# Node 2775: Bridge Degree = 3
# Node 2777: Bridge Degree = 6
# Node 2778: Bridge Degree = 5
# Node 2780: Bridge Degree = 3
# Node 2782: Bridge Degree = 2
# Node 2783: Bridge Degree = 4
# Node 2785: Bridge Degree = 5
# Node 2786: Bridge Degree = 8
# Node 2787: Bridge Degree = 3
# Node 2788: Bridge Degree = 7
# Node 2789: Bridge Degree = 5
# Node 2790: Bridge Degree = 4
# Node 2791: Bridge Degree = 3
# Node 2792: Bridge Degree = 2
# Node 2793: Bridge Degree = 2
# Node 2796: Bridge Degree = 3
# Node 2797: Bridge Degree = 4
# Node 2798: Bridge Degree = 4
# Node 2799: Bridge Degree = 4
# Node 2800: Bridge Degree = 3
# Node 2801: Bridge Degree = 2
# Node 2803: Bridge Degree = 3
# Node 2804: Bridge Degree = 3
# Node 2806: Bridge Degree = 7
# Node 2808: Bridge Degree = 3
# Node 2809: Bridge Degree = 2
# Node 2811: Bridge Degree = 5
# Node 2815: Bridge Degree = 3
# Node 2816: Bridge Degree = 3
# Node 2821: Bridge Degree = 3
# Node 2822: Bridge Degree = 8
# Node 2826: Bridge Degree = 6
# Node 2829: Bridge Degree = 4
# Node 2832: Bridge Degree = 3
# Node 2833: Bridge Degree = 3
# Node 2834: Bridge Degree = 2
# Node 2836: Bridge Degree = 2
# Node 2837: Bridge Degree = 5
# Node 2838: Bridge Degree = 4
# Node 2840: Bridge Degree = 3
# Node 2841: Bridge Degree = 5
# Node 2843: Bridge Degree = 4
# Node 2845: Bridge Degree = 5
# Node 2846: Bridge Degree = 3
# Node 2847: Bridge Degree = 2
# Node 2848: Bridge Degree = 4
# Node 2849: Bridge Degree = 6
# Node 2852: Bridge Degree = 3
# Node 2853: Bridge Degree = 3
# Node 2854: Bridge Degree = 5
# Node 2855: Bridge Degree = 9
# Node 2856: Bridge Degree = 6
# Node 2858: Bridge Degree = 7
# Node 2859: Bridge Degree = 4
# Node 2861: Bridge Degree = 2
# Node 2862: Bridge Degree = 5
# Node 2863: Bridge Degree = 2
# Node 2864: Bridge Degree = 2
# Node 2865: Bridge Degree = 3
# Node 2867: Bridge Degree = 2
# Node 2868: Bridge Degree = 3
# Node 2869: Bridge Degree = 7
# Node 2871: Bridge Degree = 3
# Node 2875: Bridge Degree = 2
# Node 2877: Bridge Degree = 5
# Node 2878: Bridge Degree = 3
# Node 2879: Bridge Degree = 3
# Node 2882: Bridge Degree = 6
# Node 2883: Bridge Degree = 5
# Node 2885: Bridge Degree = 4
# Node 2886: Bridge Degree = 2
# Node 2887: Bridge Degree = 3
# Node 2888: Bridge Degree = 3
# Node 2889: Bridge Degree = 6
# Node 2895: Bridge Degree = 3
# Node 2901: Bridge Degree = 5
# Node 2902: Bridge Degree = 3
# Node 2903: Bridge Degree = 3
# Node 2904: Bridge Degree = 2
# Node 2905: Bridge Degree = 3
# Node 2906: Bridge Degree = 4
# Node 2907: Bridge Degree = 7
# Node 2908: Bridge Degree = 5
# Node 2910: Bridge Degree = 2
# Node 2912: Bridge Degree = 2
# Node 2913: Bridge Degree = 2
# Node 2917: Bridge Degree = 2
# Node 2918: Bridge Degree = 6
# Node 2920: Bridge Degree = 2
# Node 2921: Bridge Degree = 7
# Node 2922: Bridge Degree = 6
# Node 2927: Bridge Degree = 3
# Node 2928: Bridge Degree = 2
# Node 2929: Bridge Degree = 2
# Node 2930: Bridge Degree = 3
# Node 2932: Bridge Degree = 7
# Node 2933: Bridge Degree = 4
# Node 2939: Bridge Degree = 6
# Node 2940: Bridge Degree = 7
# Node 2941: Bridge Degree = 6
# Node 2947: Bridge Degree = 5
# Node 2948: Bridge Degree = 5
# Node 2952: Bridge Degree = 2

# %%
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G, seed=42)  # 使用Spring布局
nx.draw_networkx_nodes(G, pos, node_size=20, node_color="blue")  # 绘制所有节点
nx.draw_networkx_nodes(G, pos, nodelist=bridge_nodes, node_size=50, node_color="red")  # 用不同的颜色和大小绘制桥接节点
nx.draw_networkx_edges(G, pos, alpha=0.1)  # 绘制边
plt.title("Network with Bridge Nodes Highlighted")
plt.show()

# %%
# 计算filtered_nodes中每个节点的桥接度
filtered_bridge_degree = {}
for node in filtered_nodes:
    if node in bridge_degree:
        filtered_bridge_degree[node] = bridge_degree[node]

# 打印结果
print("Bridge Degree for Filtered Nodes:")
for node, degree in filtered_bridge_degree.items():
    print(f"Node {node}: Bridge Degree = {degree}")
# Out:
# Bridge Degree for Filtered Nodes:
# Node 2539: Bridge Degree = 10
# Node 563: Bridge Degree = 9
# Node 646: Bridge Degree = 8
# Node 2579: Bridge Degree = 9
# Node 819: Bridge Degree = 10
# Node 2419: Bridge Degree = 8

# %%
# 9. 移除桥接节点，看看它对网络结构有什么影响

for node in filtered_nodes:
    G_copy = G.copy()
    # 移除桥接节点
    G_copy.remove_node(node)
    # 检查网络是否仍然连通
    is_connected = nx.is_connected(G_copy)
    print(f"Removing node {node}, is the graph still connected? {is_connected}")
# Out:
# Removing node 2539, is the graph still connected? False
# Removing node 563, is the graph still connected? False
# Removing node 646, is the graph still connected? False
# Removing node 2579, is the graph still connected? False
# Removing node 819, is the graph still connected? False
# Removing node 2419, is the graph still connected? False

# %%
# 10.计算度中心性

# 计算节点的度中心性
bridge_nodes_degree_centrality = {node: G.degree(node) / (len(G) - 1) for node in filtered_nodes}

# 打印节点的度中心性
print("Degree Centrality:")
for node, degree_centrality in bridge_nodes_degree_centrality.items():
    print(f"Node {node}: Degree Centrality = {degree_centrality}")
# Out:
# Degree Centrality:
# Node 2539: Degree Centrality = 0.1464728056004308
# Node 563: Degree Centrality = 0.07969843834141088
# Node 646: Degree Centrality = 0.0791599353796446
# Node 2579: Degree Centrality = 0.11954765751211632
# Node 819: Degree Centrality = 0.046849757673667204
# Node 2419: Degree Centrality = 0.09100700053850296

# %%
import networkx as nx
import community as community_louvain

# 使用Louvain算法检测社区
partition = community_louvain.best_partition(G)

# 计算每个社区的有效规模
community_effective_sizes = {}
for community in set(partition.values()):
    # 找出属于当前社区的节点
    community_nodes = [node for node, comm in partition.items() if comm == community]
    
    # 计算社区的实际大小（即社区内部的边的数量）
    actual_size = sum(G.degree(node) for node in community_nodes) / 2
    
    # 计算社区的潜在大小（即如果每对节点之间都有边，那么会有多少边）
    potential_size = len(community_nodes) * (len(community_nodes) - 1) / 2
    
    # 计算并存储社区的有效规模
    community_effective_sizes[community] = actual_size / potential_size if potential_size != 0 else 0

# 打印结果
for community, effective_size in community_effective_sizes.items():
    print(f"Community {community}: Effective Size = {effective_size}")
# Out:
# Community 0: Effective Size = 1.0
# Community 1: Effective Size = 0.24312896405919662
# Community 2: Effective Size = 0.08273788776577204
# Community 3: Effective Size = 0.0703034262485482
# Community 4: Effective Size = 0.0898838004101162
# Community 5: Effective Size = 0.03654754937500546
# Community 6: Effective Size = 0.04796858996244452
# Community 7: Effective Size = 0.6666666666666666
# Community 8: Effective Size = 0.6666666666666666
# Community 9: Effective Size = 0.1436734693877551
# Community 10: Effective Size = 1.0
# Community 11: Effective Size = 0.04996936274509804
# Community 12: Effective Size = 0.15214761040532365
# Community 13: Effective Size = 1.0
# Community 14: Effective Size = 1.0
# Community 15: Effective Size = 1.0
# Community 16: Effective Size = 0.4
# Community 17: Effective Size = 1.0
# Community 18: Effective Size = 1.1666666666666667
# Community 19: Effective Size = 0.7666666666666667
# Community 20: Effective Size = 0.5
# Community 21: Effective Size = 0.6666666666666666
# Community 22: Effective Size = 0.4
# Community 23: Effective Size = 1.0
# Community 24: Effective Size = 1.0
# Community 25: Effective Size = 0.17320261437908496
# Community 26: Effective Size = 1.0
# Community 27: Effective Size = 0.5
# Community 28: Effective Size = 0.07811753463927378
# Community 29: Effective Size = 1.0
# Community 30: Effective Size = 0.6666666666666666
# Community 31: Effective Size = 0.5
# Community 32: Effective Size = 1.0
# Community 33: Effective Size = 0.2857142857142857
# Community 34: Effective Size = 1.0
# Community 35: Effective Size = 0.6666666666666666

# %%
# 11.计算filtered_nodes中每个节点所在社区的有效规模

filtered_effective_sizes = {}
for node in filtered_nodes:
    community = partition[node]  # 找出节点所在的社区
    filtered_effective_sizes[node] = community_effective_sizes[community]

# 打印结果
print("Effective Size for Nodes in Filtered Nodes:")
for node, effective_size in filtered_effective_sizes.items():
    print(f"Node {node}: Effective Size = {effective_size}")
# Out:
# Effective Size for Nodes in Filtered Nodes:
# Node 2539: Effective Size = 0.03654754937500546
# Node 563: Effective Size = 0.08273788776577204
# Node 646: Effective Size = 0.04996936274509804
# Node 2579: Effective Size = 0.03654754937500546
# Node 819: Effective Size = 0.04796858996244452
# Node 2419: Effective Size = 0.0703034262485482

# %%
# 计算filtered_nodes中每个节点的等级度
filtered_hierarchy = {}
for node in filtered_nodes:
    neighbors = set(G.neighbors(node))  # 找出节点的所有邻居
    if len(neighbors) > 1:  # 如果节点有多于一个的邻居
        connected_neighbors = sum(1 for i in neighbors for j in neighbors if i != j and G.has_edge(i, j))  # 计算邻居之间的连接数
        filtered_hierarchy[node] = connected_neighbors / (len(neighbors) * (len(neighbors) - 1))  # 计算等级度
    else:
        filtered_hierarchy[node] = 0  # 如果节点只有一个或没有邻居，那么它的等级度为0

# 打印结果
for node, hier in filtered_hierarchy.items():
    print(f"Node {node}: Hierarchy = {hier}")
# Out:
# Node 2539: Hierarchy = 0.05727696982852182
# Node 563: Hierarchy = 0.06600478029049457
# Node 646: Hierarchy = 0.024787997390737115
# Node 2579: Hierarchy = 0.06628347804818394
# Node 819: Hierarchy = 0.04143277198609997
# Node 2419: Hierarchy = 0.045787545787545784

# %%
import pandas as pd

# 创建一个数据框来存储你的数据
df = pd.DataFrame({
    'Node': filtered_nodes,
    'Betweenness Centrality': [round(betweenness_centralities[node], 4) for node in filtered_nodes],
    'Constraint': [-round(node_constraints[node][node], 4) for node in filtered_nodes],  # 负相关的指标
    'PageRank': [round(pageranks[node], 4) for node in filtered_nodes],
    'Local Clustering Coefficient': [-round(local_clustering_coefficients[node], 4) for node in filtered_nodes],  # 负相关的指标
    'Degree Centrality': [round(bridge_nodes_degree_centrality[node], 4) for node in filtered_nodes],
    'Community Effective Size': [-round(filtered_effective_sizes[node], 4) for node in filtered_nodes],  # 负相关的指标
    'Hierarchy': [round(filtered_hierarchy[node], 4) for node in filtered_nodes]
})

# 设置Node列为索引
df.set_index('Node', inplace=True)

# 打印数据框
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(df)
# Out:
#       Betweenness Centrality  Constraint  PageRank  \
# Node
# 2539                  0.0796     -0.0084    0.0086
# 563                   0.0596     -0.0115    0.0049
# 646                   0.0533     -0.0103    0.0058
# 2579                  0.0386     -0.0097    0.0066
# 819                   0.0355     -0.0159    0.0035
# 2419                  0.0328     -0.0101    0.0054
#
#       Local Clustering Coefficient  Degree Centrality  \
# Node
# 2539                       -0.0573             0.1465
# 563                        -0.0660             0.0797
# 646                        -0.0248             0.0792
# 2579                       -0.0663             0.1195
# 819                        -0.0414             0.0468
# 2419                       -0.0458             0.0910
#
#       Community Effective Size  Hierarchy
# Node
# 2539                   -0.0365     0.0573
# 563                    -0.0827     0.0660
# 646                    -0.0500     0.0248
# 2579                   -0.0365     0.0663
# 819                    -0.0480     0.0414
# 2419                   -0.0703     0.0458

# %%
# 计算综合得分
df['Score'] = df.sum(axis=1)

# 打印分数列
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(df['Score'])
# Out:
# Node
# 2539    0.1898
# 563     0.0500
# 646     0.0780
# 2579    0.1185
# 819     0.0219
# 2419    0.0488
# Name: Score, dtype: float64

# %%
from IPython.display import display, HTML

# 生成HTML表格
html = df.to_html(classes='center')

# 添加CSS
html = html + """
<style>
.center {
    text-align: center;
}
</style>
"""

display(HTML(html))
# Out:
# <table border="1" class="dataframe center">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Betweenness Centrality</th>
#       <th>Constraint</th>
#       <th>PageRank</th>
#       <th>Local Clustering Coefficient</th>
#       <th>Degree Centrality</th>
#       <th>Community Effective Size</th>
#       <th>Hierarchy</th>
#       <th>Score</th>
#     </tr>
#     <tr>
#       <th>Node</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2539</th>
#       <td>0.0796</td>
#       <td>-0.0084</td>
#       <td>0.0086</td>
#       <td>-0.0573</td>
#       <td>0.1465</td>
#       <td>-0.0365</td>
#       <td>0.0573</td>
#       <td>0.1898</td>
#     </tr>
#     <tr>
#       <th>563</th>
#       <td>0.0596</td>
#       <td>-0.0115</td>
#       <td>0.0049</td>
#       <td>-0.0660</td>
#       <td>0.0797</td>
#       <td>-0.0827</td>
#       <td>0.0660</td>
#       <td>0.0500</td>
#     </tr>
#     <tr>
#       <th>646</th>
#       <td>0.0533</td>
#       <td>-0.0103</td>
#       <td>0.0058</td>
#       <td>-0.0248</td>
#       <td>0.0792</td>
#       <td>-0.0500</td>
#       <td>0.0248</td>
#       <td>0.0780</td>
#     </tr>
#     <tr>
#       <th>2579</th>
#       <td>0.0386</td>
#       <td>-0.0097</td>
#       <td>0.0066</td>
#       <td>-0.0663</td>
#       <td>0.1195</td>
#       <td>-0.0365</td>
#       <td>0.0663</td>
#       <td>0.1185</td>
#     </tr>
#     <tr>
#       <th>819</th>
#       <td>0.0355</td>
#       <td>-0.0159</td>
#       <td>0.0035</td>
#       <td>-0.0414</td>
#       <td>0.0468</td>
#       <td>-0.0480</td>
#       <td>0.0414</td>
#       <td>0.0219</td>
#     </tr>
#     <tr>
#       <th>2419</th>
#       <td>0.0328</td>
#       <td>-0.0101</td>
#       <td>0.0054</td>
#       <td>-0.0458</td>
#       <td>0.0910</td>
#       <td>-0.0703</td>
#       <td>0.0458</td>
#       <td>0.0488</td>
#     </tr>
#   </tbody>
# </table>
# <style>
# .center {
#     text-align: center;
# }
# </style>

# %%
# 新增：数据集概况

# 获取数据集概况
total_nodes = len(G.nodes())  # 总节点数
total_communities = len(set(partition.values()))  # 总社区数
total_edges = len(G.edges())  # 总连接数

# 打印数据集概况
print(f"总节点数: {total_nodes}")
print(f"总社区数: {total_communities}")
print(f"总连接数: {total_edges}")
# Out:
# 总节点数: 1858
# 总社区数: 36
# 总连接数: 12534

# %%
# 可视化数据集概况
plt.figure(figsize=(8, 6))
plt.bar(["节点数", "社区数", "连接数"], [total_nodes, total_communities, total_edges], color=["blue", "green", "red"])
plt.xlabel("属性")
plt.ylabel("数量")
plt.title("数据集概况")
plt.show()
